# %%
import sys
sys.path
# Out:
# ['/home/ls/miniconda3/envs/kaggle/lib/python314.zip',
#  '/home/ls/miniconda3/envs/kaggle/lib/python3.14',
#  '/home/ls/miniconda3/envs/kaggle/lib/python3.14/lib-dynload',
#  '',
#  '/home/ls/miniconda3/envs/kaggle/lib/python3.14/site-packages']
